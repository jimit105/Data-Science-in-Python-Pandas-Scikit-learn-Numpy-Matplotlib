# %% [markdown]
# # Web Scraping

# %% [markdown]
# > **Web scraping** is a computer software technique of extracting information from websites.
# This technique mostly focuses on the transformation of unstructured data (HTML format) on the web into structured data (database or spreadsheet).

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ## Web Scraping Process
#
# 1. Download HTML of web page
# 2. Locate information of interest
# 3. Locate element inside HTML source code- common pattern
# 4. Give instructions to Scrapper/Extractor to give all elements of the desired pattern

# %% [markdown]
# ## Search by Tag and TagByClass

# %%
# To download full text form particular URL
import requests

from bs4 import BeautifulSoup

# %%
url = "http://www.imdb.com/chart/boxoffice/"
html = requests.get(url)

# %%
html.text
# Out:
# '\n\n\n\n<!DOCTYPE html>\n<html\nxmlns:og="http://ogp.me/ns#"\nxmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    \n    \n    \n\n    \n    \n    \n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">\n            <style>\n                body#styleguide-v2 {\n                    background: no-repeat fixed center top #000;\n                }\n            </style>\n            <script type="text/javascript">var ue_t0=window.ue_t0||+new Date();</script>\n            <script type="text/javascript">\n                var ue_mid = "A1EVAM02EL8SFB"; \n                var ue_sn = "www.imdb.com";  \n                var ue_furl = "fls-na.amazon.com";\n                var ue_sid = "000-0000000-0000000";\n                var ue_id = "0SRMK5BP6ZVB6NVGPY84";\n                (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-11e51f253e8ad9d145f4ed644b40f692._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);\n                if (!(\'CS\' in window)) { window.CS = {}; }\n                    window.CS.loginLocation = "https://www.imdb.com/registration/signin?u=%2Fchart%2Fboxoffice%2F";\n            </script>\n \n\n        \n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>IMDb Top Box Office - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }\n</script>\n<script>\n    if (typeof uex == \'function\') {\n      uex("ld", "LoadTitle", {wb: 1});\n    }\n</script>\n        \n            <link rel="canonical" href="http://www.imdb.com/chart/boxoffice/" />\n            <meta property="og:url" content="http://www.imdb.com/chart/boxoffice/" />\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadIcons", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);</script>\n        <link href="http://ia.media-imdb.com/images/G/01/imdb/images/safari-favicon-517611381._CB514892156_.svg" mask rel="icon" sizes="any">\n        <link rel="icon" type="image/ico" href="http://ia.media-imdb.com/images/G/01/imdb/images/favicon-2165806970._CB514892157_.ico" />\n        <meta name="theme-color" content="#000000" />\n        <link rel="shortcut icon" type="image/ ...

# %%
#Convert HTML source code to soup object
bsObj = BeautifulSoup(html.text, 'lxml')

# %%
bsObj
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
# <style>
#                 body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#             </style>
# <script type="text/javascript">var ue_t0=window.ue_t0||+new Date();</script>
# <script type="text/javascript">
#                 var ue_mid = "A1EVAM02EL8SFB";
#                 var ue_sn = "www.imdb.com";
#                 var ue_furl = "fls-na.amazon.com";
#                 var ue_sid = "000-0000000-0000000";
#                 var ue_id = "0SRMK5BP6ZVB6NVGPY84";
#                 (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-11e51f253e8ad9d145f4ed644b40f692._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);
#                 if (!('CS' in window)) { window.CS = {}; }
#                     window.CS.loginLocation = "https://www.imdb.com/registration/signin?u=%2Fchart%2Fboxoffice%2F";
#             </script>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>IMDb Top Box Office - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="http://www.imdb.com/chart/boxoffice/" rel="canonical"/>
# <meta content="http://www.imdb.com/chart/boxoffice/" property="og:url"/>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadIcons", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);</script>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/safari-favicon-517611381._CB514892156_.svg" mask="" rel="icon" sizes="any"/>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/favicon-2165806970._CB514892157_.ico" rel="icon" type="image/ico"/>
# <meta content="#000000" name="theme-color"/>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB522736561_.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-4151659188._CB514891867_.png" rel="apple-touch-icon"/>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-76x76-53536248._CB514891820_.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-120x120-2442878471._CB514893789_.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-152x152-1475823641._CB514891827_.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/imdbsearch-3349468880._CB514892150_.xml" rel="search" title="IMDb" type="application/opensearchdescription+xml"/>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_icon"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadIcons", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadIcons", {wb: 1});
#     }
# </script>
# <title>IMDb Top Box Office</title>
# <meta content="Check out the top movies at the box office on IMDb" name="description"/>
# <meta content="index,follow" name="robots"/>
# <meta content="Check out the top movies at the box office on IMDb" itemprop="description"/>
# <meta content="images/logos/imdb_fb_logo.png" itemprop="image"/>
# <meta content="IMDb Top Box Office" itemprop="name"/>
# <meta content="chart" property="pageType"/>
# <meta content="boxoffice" property="subpageType"/>
# <meta content="0SRMK5BP6ZVB6NVGPY84" name="requestId"/>
# <meta content="115109575169727" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="Check out the top movies at the box office on IMDb" property="og:description"/>
# <meta content="images/logos/imdb_fb_logo.png" property="og:image"/>
# <meta content="IMDb" property="og:site_name"/>
# <meta content="IMDb Top Box Office" property="og:title"/>
# <meta content="Check out the top movies at the box office on IMDb" name="twitter:description"/>
# <meta content="images/logos/imdb_fb_logo.png" name="twitter:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@IMDb" name="twitter:site"/>
# <meta content="IMDb Top Box Office" name="twitter:title"/>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadCSS", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_css"] = new Date().getTime(); })(IMDbTimer);</script>
# <!-- h=ics-1e-c4-2xl-8c1eb0a4.us-east-1 -->
# <link href="http://ia.media-imdb.com/images/G/01/imdb/css/collections/consumer-2-column-910688681._CB491153517_.css" rel="stylesheet" type="text/css"/>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/css/collections/other-2848344672._CB514892132_.css" rel="stylesheet" type="text/css"/>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/css/collections/watchlistButton-3806422028._CB514893458_.css" rel="stylesheet" type="text/css"/>
# <noscript>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/css/wheel/nojs-2827156349._CB514892070_.css" rel="stylesheet" type="text/css"/>
# </noscript>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_css"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadCSS", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadCSS", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadJS", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_ads"] = new Date().getTime(); })(IMDbTimer);</script>
# <script type="text/javascript">
#             // ensures js doesn't die if ads service fails.
#             // Note that we need to define the js here, since ad js is being rendered inline after this.
#             (function(f) {
#                 // Fallback javascript, when the ad Service call fails.
#
#                 if((window.csm == null || window.generic == null || window.consoleLog == null)) {
#                     if (window.console && console.log) {
#                         console.log("one or more of window.csm, window.generic or window.consoleLog has been stubbed...");
#                     }
#                 }
#
#                 window.csm = window.csm || { measure:f, record:f, duration:f, listen:f, metrics:{} };
#                 window.generic = window.generic || { monitoring: { start_timing: f, stop_timing: f } };
#                 window.consoleLog = window.consoleLog || f;
#             })(function() {});
#         </script>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_head_delivery_finished');
#     }
#   </script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadJS", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadJS", {wb: 1});
#     }
# </script>
# </head>
# <body class="fixed" id="styleguide-v2">
# <script>
#     if (typeof uet == 'function') {
#       uet("bb");
#     }
# </script>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_body_delivery_started');
#     }
#   </script>
# <div id="wrapper">
# <div class="redesign" id="root">
# <script>
#     if (typeof uet == 'function') {
#       uet("ns");
#     }
# </script>
# <div class="navbarSprite" id="nb20">
# <div id="supertab">
# <!-- no content received for slot: top_ad -->
# </div>
# <div class="navbarSprite" id="navbar">
# <noscript>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/css/site/consumer-navbar-no-js-3652782989._CB514893318_.css" rel="stylesheet" type="text/css"/>
# </noscript>
# <!--[if IE]><link rel="stylesheet" type="text/css" href="http://ia.media-imdb.com/images/G/01/imdb/css/site/consumer-navbar-ie-2133976414._CB514893341_.css"><![endif]-->
# <span id="home_img_holder">
# <a class="navbarSprite" href="/?ref_=nv_home" id="home_img" title="Home"></a> <span class="alt_logo">
# <a href="/?ref_=nv_home" title="Home">IMDb</a>
# </span>
# </span>
# <form action="/find" class="nav-searchbar-inner" id="navbar-form" method="get">
# <div id="nb_search">
# <noscript><div id="more_if_no_javascript"><a href="/search/">More</a></div></noscript>
# <button class="primary btn" id="navbar-submit-button" type="submit"><div class="magnifyingglass navbarSprite"></div></button>
# <input name="ref_" type="hidden" value="nv_sr_fn"/>
# <input autocomplete="off" id="navbar-query" name="q" placeholder="Find Movies, TV shows, Celebrities and more..." type="text" value=""/>
# <div class="quicksearch_dropdown_wrapper">
# <select class="quicksearch_dropdown navbarSprite hidden" id="quicksearch" name="s">
# <option value="all">All</option>
# <option value="tt">Titles</option>
# <option value="ep">TV Episodes</option>
# <option value="nm">Names</option>
# <option value="co">Companies</option>
# <option value="kw">Keywords</option>
# <option value="qu">Quotes</option>
# <option value="bi">Bios</option>
# <option value="pl">Plots</option>
# </select>
# </div>
# <div id="navbar-suggestionsearch"></div>
# </div>
# </form>
# <div id="megaMenu">
# <ul class="main_nav" id="consumer_main_nav">
# <li class="spacer"></li>
# <li class="css_nav_item" id="navTitleMenu">
# <p class="navCategory">
# <a href="/movies-in-theaters/?ref_=nv_tp_inth_1">Movies</a>,
#                 <a href="/chart/toptv/?ref_=nv_tp_tv250_2">TV</a><br/>
#                 &amp; <a href="/showtimes/?ref_=nv_tp_sh_3">Showtimes</a></p>
# <span class="downArrow"></span>
# <div class="sub_nav" id="navMenu1">
# <div id="titleMenuImage" style="background: url('http://ia.media-imdb.com/images/M/MV5BMTM1NTYzOTE4Ml5BMl5BanBnXkFtZTYwNzUwOTQ2._V1._UY315_CR0,0,410,315_.jpg')">
# <a class="fallback" href="/title/tt0057012/?ref_=nv_mv_dflt_1" title="                            Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# <a href="/offsite/?page-action=fol_fb&amp;token=BCYtlLZhPP3ui1OB92Lg1TYFOxtIx8s1qiMuw0s8Q4j2KIQkBEVmlFF-eQbAnKp00HAa6ZlwggiT%0D%0ArtUS_zZysK_AKYboszZaQ6zHkw2YMcmI2Yg2fYwQu-06tRojIumU-pZw9AB2ptgClWSyUyJVLWlr%0D%0ArIlLC-BGd2FP2EAPgSxnFlRNa7tR_a-MM4DpN4ttY3DktVDUn_Y3ndh8yhKi67SW2Q%0D%0A&amp;ref_=chtbo_nv_fol_fb" itemprop="url" target="_blank" title="Follow IMDb on Facebook"> <span class="desktop-sprite follow-facebook"></span>
# </a>
# <a href="/offsite/?page-action=fol_tw&amp;token=BCYuXK_1ZpriV9F04dJaEXrA5EZ5gE8l6q0roUHxAj4S_tanok16NNRT3tTBuGgEgEuR3qTQ2bxB%0D%0AP8ZdoOkckhU6_LaVBqZvrmJNJepz8QVDsvkI97GdIhHB9XEolJvvE9kT39tmhFzPZbhni1jkDscJ%0D%0Ai1HuiU9yRAh9TJnBAyjY3ySh3wa8KpCMFrVVNr6CbUUOehRmygODFHnPISr-cK6QBA%0D%0A&amp;ref_=chtbo_nv_fol_tw" itemprop="url" target="_blank" title="Follow IMDb on Twitter"> <span class="desktop-sprite follow-twitter"></span>
# </a>
# <a href="/offsite/?page-action=fol_inst&amp;token=BCYjPeSangdYELiNmUzwcm7XOF3BLxrmSeRCgbLe0AorN7MaYoBiPKZ7l8EGKMfmB9dh_MZmBGUx%0D%0Adu6w-0j8MXDW1-kNtEPy8vAHExCsH7E26LQr2Vs8yen0xieIbj28BVh0xHdmGKTup8ueN1hkurqr%0D%0AkrGK6EgObOJI8G-Oa450_ilIhuFU4hS3FJTVvRj8VdnWK7bYffFxDwIljygxlNiStA%0D%0A&amp;ref_=chtbo_nv_fol_inst" itemprop="url" target="_blank" title="Follow IMDb on Instagram"> <span class="desktop-sprite follow-instagram"></span>
# </a>
# </li>
# </ul>
# </div>
# <div id="nb_personal">
# <ul class="main_nav" id="consumer_user_nav">
# <li class="css_nav_menu no_arrow" id="navUserMenu">
# <p class="navCategory singleLine">
# <a class="signin-button" href="https://graph.facebook.com/v2.8/oauth/authorize?client_id=127059960673829&amp;scope=email%2Cuser_about_me%2Cuser_birthday&amp;state=eyI0OWU2YyI6ImRhMjkiLCJ1IjoiaHR0cHM6Ly93d3cuaW1kYi5jb20vP3JlZl89bnZfZmJfbGdpbiIsIm1hbnVhbExpbmsiOiJmYWxzZSJ9&amp;redirect_uri=https%3A%2F%2Fwww.imdb.com%2Fregistration%2Ffacebookhandler%2F" id="facebook-signin-link">
# <span class="facebook-logo"></span>
# <span class="signin-facebook-text">Sign in with Facebook</span></a>
# <a class="signin-other-options-text" href="https://www.imdb.com/registration/signin?u=/chart/boxoffice/&amp;ref_=nv_usr_lgin_1" id="nblogin" rel="login">Other Sign in options</a>
# </p>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- no content received for slot: navstrip -->
# <!-- no content received for slot: injected_navstrip -->
# <script>
#     if (typeof uet == 'function') {
#       uet("ne");
#     }
# </script>
# <script>
#     if (typeof uet == 'function') {
#       uet("cf");
#     }
# </script>
# <div id="pagecontent">
# <div class="pagecontent">
# <!-- no content received for slot: injected_billboard -->
# </div>
# <div class="pagecontent" id="top-slot-wrapper">
# </div>
# <div class="pagecontent">
# <div id="content-2-wide">
# <div id="main">
# <script>
#     if (typeof uet == 'function') {
#       uet("af");
#     }
# </script>
# <a name="slot_center-1"></a>
# <div class="article">
# <script type="text/javascript">if(typeof uet === 'function'){uet('bb','BoxOfficeChartWidget',{wb:1});}</script>
# <span class="ab_widget">
# <h1 class="header">Top Box Office (US)</h1>
# <div class="article listo" id="boxoffice">
# <div class="chart-social-sharing-widget" id="social-sharing-widget"></div>
# <h4>Weekend of December 15 - 17, 2017</h4>
# <br/>
# <table class="chart full-width" data-caller-name="chart-boxoffice">
# <colgroup>
# <col class="chartTableColumnPoster"/>
# <col class="chartTableColumnTitle"/>
# <col class="chartTableGross"/>
# <col class="chartTableGross"/>
# <col class="chartTableWeeks"/>
# <col class="chartTableColumnWatchlistRibbon"/>
# </colgroup>
# <thead>
# <tr>
# <th></th>
# <th>Title</th>
# <th>Weekend</th>
# <th>Gross</th>
# <th>Weeks</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt2527336?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_1"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjQ1MzcxNjg4N15BMl5BanBnXkFtZTgwNzgwMjY4MzI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td><td class="titleColumn">
# <a href="/title/tt2527336?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_1" title="Rian Johnson (dir.), Daisy Ridley, John Boyega">Star Wars: Episode VIII - The Last Jedi</a>
# </td>
# <td class="ratingColumn">
#                             $220.0M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$220.0M</span>
# </td>
# <td class="weeksColumn">1</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt2527336"></div></td>
# </tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt3411444?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_2"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BOTIwMDI0NjQ4OF5BMl5BanBnXkFtZTgwNjU0MzAyNDM@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td><td class="titleColumn">
# <a href="/title/tt3411444?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_2" title="Carlos Saldanha (dir.), John Cena, Kate McKinnon">Ferdinand</a>
# </td>
# <td class="ratingColumn">
#                             $13.3M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$13.3M</span>
# </td>
# <td class="weeksColumn">1</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt3411444"></div></td>
# </tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt2380307?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_3"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYjQ5NjM0Y2YtNjZkNC00ZDhkLWJjMWItN2QyNzFkMDE3ZjAxXkEyXkFqcGdeQXVyODIxMzk5NjA@._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
# </a> </td><td class="titleColumn">
# <a href="/title/tt2380307?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_3" title="Lee Unkrich (dir.), Anthony Gonzalez, Gael García Bernal">Coco</a>
# </td>
# <td class="ratingColumn">
#                             $10.0M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$150.8M</span>
# </td>
# <td class="weeksColumn">4</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt2380307"></div></td>
# </tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt2543472?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_4"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYjFhOWY0OTgtNDkzMC00YWJkLTk1NGEtYWUxNjhmMmQ5ZjYyXkEyXkFqcGdeQXVyMjMxOTE0ODA@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td><td class="titleColumn">
# <a href="/title/tt2543472?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_4" title="Stephen Chbosky (dir.), Jacob Tremblay, Owen Wilson">Wonder</a>
# </td>
# <td class="ratingColumn">
#                             $5.4M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$109.3M</span>
# </td>
# <td class="weeksColumn">5</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt2543472"></div></td>
# </tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt0974015?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_5"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYWVhZjZkYTItOGIwYS00NmRkLWJlYjctMWM0ZjFmMDU4ZjEzXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td><td class="titleColumn">
# <a href="/title/tt0974015?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_5" title="Zack Snyder (dir.), Ben Affleck, Gal Gadot">Justice League</a>
# </td>
# <td class="ratingColumn">
#                             $4.2M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$219.5M</span>
# </td>
# <td class="weeksColumn">5</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt0974015"></div></td>
# </tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt5657846?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_6"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BNDA4Nzc1OTg2OV5BMl5BanBnXkFtZTgwODE3ODgwNDI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td><td class="titleColumn">
# <a href="/title/tt5657846?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_6" title="Sean Anders (dir.), Will Ferrell, Mark Wahlberg">Daddy's Home 2</a>
# </td>
# <td class="ratingColumn">
#                             $3.8M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$96.6M</span>
# </td>
# <td class="weeksColumn">6</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt5657846"></div></td>
# </tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt3501632?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_7"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjMyNDkzMzI1OF5BMl5BanBnXkFtZTgwODcxODg5MjI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td><td class="titleColumn">
# <a href="/title/tt3501632?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_7" title="Taika Waititi (dir.), Chris Hemsworth, Tom Hiddleston">Thor: Ragnarok</a>
# </td>
# <td class="ratingColumn">
#                             $3.0M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$306.4M</span>
# </td>
# <td class="weeksColumn">7</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt3501632"></div></td>
# </tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt3521126?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_8"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BOGNkMzliMGMtMDI5Ni00OTZkLTgyMTYtNzk5ZTY1NjVhYjVmXkEyXkFqcGdeQXVyNTAzMTY4MDA@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td><td class="titleColumn">
# <a href="/title/tt3521126?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_8" title="James Franco (dir.), James Franco, Dave Franco">The Disaster Artist</a>
# </td>
# <td class="ratingColumn">
#                             $2.6M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$12.9M</span>
# </td>
# <td class="weeksColumn">3</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt3521126"></div></td>
# </tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt3402236?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_9"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BNGFmM2NmYjYtMjAwNy00ZDkzLWI3ZWMtOGZhOTRhYzQwMTA0XkEyXkFqcGdeQXVyNzU2MzMyNTI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td><td class="titleColumn">
# <a href="/title/tt3402236?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_9" title="Kenneth Branagh (dir.), Kenneth Branagh, Penélope Cruz">Murder on the Orient Express</a>
# </td>
# <td class="ratingColumn">
#                             $2.5M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$97.3M</span>
# </td>
# <td class="weeksColumn">6</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt3402236"></div></td>
# </tr>
# <tr>
# <td class="posterColumn">
# <a href="/title/tt4925292?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_10"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjg1NDY0NDYzMV5BMl5BanBnXkFtZTgwNzIwMTEwNDI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td><td class="titleColumn">
# <a href="/title/tt4925292?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417680642&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=cht_bo_10" title="Greta Gerwig (dir.), Saoirse Ronan, Timothée Chalamet">Lady Bird</a>
# </td>
# <td class="ratingColumn">
#                             $2.1M
#                     </td>
# <td class="ratingColumn">
# <span class="secondaryInfo">$26.0M</span>
# </td>
# <td class="weeksColumn">7</td>
# <td class="watchlistColumn"><div class="wlb_ribbon" data-tconst="tt4925292"></div></td>
# </tr>
# </tbody>
# </table>
# <div class="reported text-smaller">
#             Reported by
#             <a href="/offsite/?page-action=offsite-boxofficemojo&amp;token=BCYuwu_F7y9u0Pa1LAtNKyUydxdGAZ3JHYia0c4Le-Kfy9hJb8Y7f53JF7J8vD43fAw7qbXSS2Al%0D%0AB4ppHnEgVDyLQHQbFrayohuuT11lSexD9CkQ52fOJmwWhJg-cgnwAoQWRpld2Bc9FjdeyV75XxcK%0D%0AwiJyIZtfQN0jlpeSa5_eD4vuwiaVjBcBe8G7SyMrSTcWPlDVgYd-dZsOw6Rhigdjtw%0D%0A">Box Office Mojo</a>
#             © 2017
#         </div>
# <hr/>
# <a href="/offsite/?page-action=offsite-boxofficemojo&amp;token=BCYqdha2A24L9MLYjVlZp-R6tTHICD_0XD-qrXckvLdSBEkD5g1znSQ8HBkVdKxk7TvyPj7-HUpq%0D%0A-2dzgghnxpOaIac2GAUUAzmC4Ol3wwofCwt8s_fYlQ68LyZuOAyWs-ksECRPBz4fQDybLbQ5Y87E%0D%0AVZ6K5JYO1dDhMZ54amm5wS4h4QhE6YAr2N2qy608SJaT_C5U6NzhOZtqR4pseVnzFg%0D%0A">See more box office results at BoxOfficeMojo.com</a> »
#     </div>
# </span>
# <script type="text/javascript">
#                 if(typeof uex === 'function'){uex('ld','BoxOfficeChartWidget',{wb:1});}
#                 if(typeof uet === 'function'){uet("af");}
#             </script>
# </div>
# </div>
# <div id="sidebar">
# <!-- no content received for slot: top_rhs -->
# <!-- no content received for slot: rhs_cornerstone -->
# <a name="slot_right-4"></a>
# <div class="aux-content-widget-2">
# <script type="text/javascript">if(typeof uet === 'function'){uet('bb','LinksWidget',{wb:1});}</script>
# <span class="ab_widget">
# <div class="ab_links">
# <span class="widget_header"> <span class="oneline"> <h3>IMDb Charts</h3> </span> </span> <div class="widget_content no_inline_blurb"> <div class="widget_nested"> <div class="full-table"> <div class="table-cell"> <div class="full-table"> <div class="table-row"> <div class="table-cell primary"> <a class="selected" href="/chart/boxoffice?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2671049662&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-4&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_ql_1"> Box Office </a> </div> </div> <div class="table-row"> <div class="table-cell primary"> <a href="/chart/moviemeter?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2671049662&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-4&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_ql_2"> Most Popular Movies </a> </div> </div> <div class="table-row"> <div class="table-cell primary"> <a href="/chart/top?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2671049662&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-4&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_ql_3"> Top Rated Movies </a> </div> </div> <div class="table-row"> <div class="table-cell primary"> <a href="/chart/top-english-movies?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2671049662&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-4&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_ql_4"> Top Rated English Movies </a> </div> </div> <div class="table-row"> <div class="table-cell primary"> <a href="/chart/tvmeter?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2671049662&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-4&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_ql_5"> Most Popular TV </a> </div> </div> <div class="table-row"> <div class="table-cell primary"> <a href="/chart/toptv?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2671049662&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-4&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_ql_6"> Top Rated TV </a> </div> </div> <div class="table-row"> <div class="table-cell primary"> <a href="/chart/bottom?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2671049662&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-4&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_ql_7"> Lowest Rated Movies </a> </div> </div> </div> </div> </div> </div> </div> </div>
# </span>
# <script type="text/javascript">
#                 if(typeof uex === 'function'){uex('ld','LinksWidget',{wb:1});}
#             </script>
# </div>
# <a name="slot_right-5"></a>
# <div class="aux-content-widget-2">
# <script type="text/javascript">if(typeof uet === 'function'){uet('bb','LinksWidget',{wb:1});}</script>
# <span class="ab_widget">
# <div class="ab_links">
# <span class="widget_header"> <span class="oneline"> <h3>Top India Charts</h3> </span> </span> <div class="widget_content no_inline_blurb"> <div class="widget_nested"> <div class="full-table"> <div class="table-cell"> <div class="full-table"> <div class="table-row"> <div class="table-cell primary"> <a href="/india/top-rated-indian-movies?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=3043437882&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-5&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_india_tr_rhs_1"> Top Rated Indian Movies </a> </div> </div> <div class="table-row"> <div class="table-cell primary"> <a href="/india/top-rated-malayalam-movies?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=3043437882&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-5&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_india_tr_rhs_2"> Top Rated Malayalam Movies </a> </div> </div> <div class="table-row"> <div class="table-cell primary"> <a href="/india/top-rated-tamil-movies?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=3043437882&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-5&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_india_tr_rhs_3"> Top Rated Tamil Movies </a> </div> </div> <div class="table-row"> <div class="table-cell primary"> <a href="/india/top-rated-telugu-movies/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=3043437882&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-5&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_india_tr_rhs_4"> Top Rated Telugu Movies </a> </div> </div> </div> </div> </div> </div> </div> </div>
# </span>
# <script type="text/javascript">
#                 if(typeof uex === 'function'){uex('ld','LinksWidget',{wb:1});}
#             </script>
# </div>
# <a name="slot_right-6"></a>
# <div class="aux-content-widget-2">
# <script type="text/javascript">if(typeof uet === 'function'){uet('bb','GenreWidget',{wb:1});}</script>
# <span class="ab_widget">
# <h3>Popular Movies by Genre</h3>
# <ul class="quicklinks ">
# <li class="subnav_item_main">
# <a href="/genre/action?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_1"> Action
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/adventure?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_2"> Adventure
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/animation?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_3"> Animation
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/biography?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_4"> Biography
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/comedy?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_5"> Comedy
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/crime?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_6"> Crime
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/documentary?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_7"> Documentary
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/drama?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_8"> Drama
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/family?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_9"> Family
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/fantasy?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_10"> Fantasy
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/film_noir?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_11"> Film-Noir
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/history?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_12"> History
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/horror?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_13"> Horror
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/music?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_14"> Music
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/musical?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_15"> Musical
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/mystery?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_16"> Mystery
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/romance?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_17"> Romance
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/sci_fi?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_18"> Sci-Fi
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/short?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_19"> Short
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/sport?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_20"> Sport
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/thriller?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_21"> Thriller
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/war?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_22"> War
# </a> </li>
# <li class="subnav_item_main">
# <a href="/genre/western?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2417864562&amp;pf_rd_r=0SRMK5BP6ZVB6NVGPY84&amp;pf_rd_s=right-6&amp;pf_rd_t=15506&amp;pf_rd_i=boxoffice&amp;ref_=chtbo_gnr_23"> Western
# </a> </li>
# </ul>
# </span>
# <script type="text/javascript">
#                 if(typeof uex === 'function'){uex('ld','GenreWidget',{wb:1});}
#             </script>
# </div>
# </div>
# <br class="clear"/>
# </div>
# <br class="clear"/>
# </div>
# </div>
# <div class="ft" id="footer">
# <div id="rvi-div">
# <div class="recently-viewed">
# <div class="header">
# <div class="rhs">
# <a href="#" id="clear_rvi">Clear your history</a>
# </div>
# <h3>Recently Viewed</h3>
# <br clear="all"/>
# </div>
# <div class="items"> </div>
# </div>
# <br class="clear"/>
# </div>
# <!-- no content received for slot: bottom_ad -->
# <div class="container footer-grid-wrapper">
# <div class="row footer-row">
# <div class="col outside">
# <h3>IMDb Everywhere</h3>
# <div class="app-links">
# <a href="/offsite/?page-action=ft_app_apple&amp;token=BCYhEh6FIvha2JUULqTeujB_1Bmgh0xLlHgItTveGXM5F_l7vfSNSGCMeauuY2BMXLhytJffWavn%0D%0Aw3ICcfaO4Ir3A-FDEglvzhAZ_jwIgC5RXnZPCftUs0ifNobZZnR_S6POx5BPqcb_-ACJG8v2htCX%0D%0Aby56sgQQcvAIpuseFbpmBH1GRM2dWR2g4qooS_7-ZPUnrh7PlH-jG4VrXHXOS-UYtSJ0gqZbM3J1%0D%0ASP9D4s-K5aw%0D%0A&amp;ref_=ft_app_apple" itemprop="url" target="_blank" title="Get the IMDb App on the Apple App Store"> <span class="desktop-sprite appstore-apple"></span>
# </a>
# <a href="/offsite/?page-action=ft_app
ft_fol_inst" itemprop="url" target="_blank" title="Follow IMDb on Instagram"> <span class="desktop-sprite follow-instagram"></span>
# </a>
# </div>
# </h3>
# </div>
# </div>
# <div class="col outside">
# <div class="row">
# <div class="col col-4">
# <ul class="unstyled">
# <li><a href="/?ref_=ft_hm">Home</a></li>
# <li><a href="/chart/top?ref_=ft_250">Top Rated Movies</a></li>
# <li><a href="/chart/?ref_=ft_cht">Box Office</a></li>
# <li><a href="/sections/tv/?ref_=ft_tv">TV</a></li>
# <li><a href="/movies-coming-soon/?ref_=ft_cs">Coming Soon</a></li>
# <li><a href="/a2z?ref_=ft_si">Site Index</a></li>
# <li><a href="/search?ref_=ft_sr">Search</a></li>
# <li><a href="/movies-in-theaters/?ref_=ft_inth">In Theaters</a></li>
# </ul>
# </div>
# <div class="col col-4">
# <ul class="unstyled">
# <li><a href="/helpdesk/contact?ref_=ft_con">Contact Us</a></li>
# <li> <a href="https://secure.imdb.com/register-imdb/form-v2?ref_=ft_reg">Register</a>
# </li>
# <li><a href="/news/?ref_=ft_nw">News</a></li>
# <li class="spacer"></li>
# <li><a href="/pressroom/?ref_=ft_pr">Press Room</a></li>
# <li><a href="https://advertising.amazon.com/lp/imdb?ref_=ft_ad">Advertising</a></li>
# <li><a href="/jobs?ref_=ft_jb">Jobs</a></li>
# </ul>
# </div>
# <div class="col col-4">
# <ul class="unstyled">
# <li><a href="http://pro.imdb.com/signup/index.html?rf=cons_ft_hm&amp;ref_=cons_ft_hm">IMDbPro</a></li>
# <li> <a href="/offsite/?page-action=ft-mojo&amp;token=BCYussFfkHpXHMMJjZgRtLF1jrD6xOgPsnO_EwaavkZi9sePJ0p-59B2AVcaDdgZ-HyqBEskSFTP%0D%0A9loGwyhLpP-Dyib1DWK0f5ayUDKh7OAtB5ewHGJZfK8nWuWEPBDHux2cQdgAiu7UMD4_YFWgVK6b%0D%0AsvYgdtzrtcNAk0104gj6UN7h0-7x586p9oOfAuMYV4qrxoxs4QwWCSKa-nzF5eAhxA%0D%0A&amp;ref_=ft_bom" itemprop="url">Box Office Mojo</a>
# </li>
# <li> <a href="/offsite/?page-action=ft-wab&amp;token=BCYhignUUCXmMHj8pnp0NdQG6rBNQSDiqvgn0Nkiw4l785L2meAm9suWQpHYjthODDCe1I0vPVCv%0D%0ATmUpsqebeDOciJIPmh_0lyg7KPEiakoavCWLJQ_R9L9FttXo_0E7S44k_T6xNkOQ1VwXi9xeI8k9%0D%0Au-1JBn6b9qdX0ubMsSqCUFMlf2mDmxIp2TwnocZF4Ik1orCknjrtTG95eAPZTDL2sw%0D%0A&amp;ref_=ft_wab" itemprop="url">Withoutabox</a>
# </li>
# <li class="spacer"></li>
# <li><a href="/conditions?ref_=ft_cou">Conditions of Use</a></li>
# <li><a href="/privacy?ref_=ft_pvc">Privacy Policy</a></li>
# <li> <a href="/offsite/?page-action=ft-iba&amp;token=BCYjjnh2GLWshzVzrz0vhk07fT0ZsGNFl7qO0aQO3KlJmcK1xibxGzGH8CDijzhgnQuL6Zrzpqei%0D%0ASIowG5vEyMZeZCNGp9gKZc1S_OCL93Wj7MvPixE0uxwX4iHbOYcFHpGP9bFeVg_Thh0ghJF8015P%0D%0Av67RV1s1Qq2y9DILy2zN5sfQycx9Ai9t4LUaoupPJcHuLVj51YuW5YJIQJwDUBokKSWN0ZJ-ert0%0D%0AYeB-453JXFWIa08jrDWamRxDHHrtR4Jp%0D%0A&amp;ref_=ft_iba" itemprop="url">Interest-Based Ads</a>
# </li>
# <li class="spacer"></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="ft-copy float-right">
# <a href="/conditions">Copyright ©</a> 1990-2017
#                 <a href="https://help.imdb.com/imdb?ref_=cons_ftr_imdb">IMDb.com, Inc.</a>
# </div>
# <div>
#                 An <span align="middle" class="footer_logo" id="amazon_logo">Amazon.com</span> company.
#             </div>
# </div>
# <table class="footer" id="amazon-affiliates">
# <tr>
# <td colspan="8">
#                 Amazon Affiliates
#             </td>
# </tr>
# <tr>
# <td>
# <div>
# <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-aiv&amp;token=BCYjCdFMTWzIlhpse-bLZ39viuTHcMMcpj2PHXa3PVS5_xAG7V78XX7EBWyQ-tMRmCw25yrQIUzc%0D%0Au6yT370I9RaRXFnGN9eMn2TIM_3EWtM1d4JCInpHTU_PMrm9SibXAiEunRPCCdZ5RlRMWpWR0pmN%0D%0ArhNIxBEfO5WMm6NioisRereAdB757cfJgvnzJCBMGxiPR_AcbfL0wMt4ESKTxqFNtmlI2ektqkTB%0D%0AvIurRV3ys9M%0D%0A">
0D%0A">
# <span class="amazon-affiliate-site-name">Audible</span><br/>
# <span class="amazon-affiliate-site-desc">Download<br/>Audio Books</span>
# </a>
# </div>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <script src="http://ia.media-imdb.com/images/G/01/imdb/js/collections/common-2411119445._CB514893747_.js" type="text/javascript"></script>
# <script src="http://ia.media-imdb.com/images/G/01/imdb/js/collections/pagelayout-397553245._CB492402759_.js" type="text/javascript"></script>
# <script src="http://ia.media-imdb.com/images/G/01/imdb/js/collections/other-4190749421._CB490827646_.js" type="text/javascript"></script>
# <script src="http://ia.media-imdb.com/images/G/01/imdb/js/collections/watchlistButton-1111928529._CB494056157_.js" type="text/javascript"></script>
# <script id="login" type="text/javascript">
# (function(){
#     var readyTimeout = setInterval(function() {
#         if (window.jQuery && window.imdb && window.imdb.login_lightbox) {
#             clearTimeout(readyTimeout);
#             window.imdb.login_lightbox();
#         }
#     }, 100);
# })();
# </script>
# <script type="text/javascript">
#         function jQueryOnReady(remaining_count) {
#             if (window.jQuery && typeof $.fn.watchlistRibbon !== 'undefined') {
#                 jQuery(
#                                      function() {
#                     window.imdb.CS.Chart.InitChart();
#                 }
#
#                 );
#                 jQuery(
#                      function() { $('#content-2-wide').watchlistRibbon('.ribbonize'); }
#                 );
#             } else if (remaining_count > 0) {
#                 setTimeout(function() { jQueryOnReady(remaining_count-1) }, 100);
#             }
#         }
#         jQueryOnReady(50);
#         </script>
# <div id="servertime" time="37"></div>
# <script>
#     if (typeof uet == 'function') {
#       uet("be");
#     }
# </script>
# </body>
# </html>

# %%
bsObj.find('title')
# Out:
# <title>IMDb Top Box Office - IMDb</title>

# %%
bsObj.find('title').getText()
# Out:
# 'IMDb Top Box Office - IMDb'

# %%
h1List = bsObj.findAll('h1')

# %%
for h1 in h1List:
    print(h1)
# Out:
# <h1 class="imdb-pro-ad__title">The leading information resource for the entertainment industry</h1>
# <h1 class="header">Top Box Office (US)</h1>

# %%
h4List = bsObj.findAll('h4')

# %%
for h4 in h4List:
    print(h4.getText())
# Out:
# Weekend of December 15 - 17, 2017

# %%
titleList = bsObj.findAll('td', {'class':'titleColumn'})
# Use Shift-Tab to find documentation for any method

# %%
for title in titleList:
    print(title.getText())
# Out:
# Star Wars: Episode VIII - The Last Jedi
#
#
# Ferdinand
#
#
# Coco
#
#
# Wonder
#
#
# Justice League
#
#
# Daddy's Home 2
#
#
# Thor: Ragnarok
#
#
# The Disaster Artist
#
#
# Murder on the Orient Express
#
#
# Lady Bird

# %% [markdown]
# ## Practical Activity
#
# > Fetch web page: https://www.reuters.com/finance/stocks/company-officers/GOOG.O
# Scrap the first table data from above url
# Save it to .csv file by comma separated each field.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.reuters.com/finance/stocks/company-officers/GOOG.O"
html = requests.get(url)
bsObj = BeautifulSoup(html.text, 'lxml')

# %%
file = open('ActivityCsv.csv', 'w')

# %%
trList = bsObj.findAll('tr')

for tr in trList[:1]:
    thList = tr.findAll('th')
    text=""
    for th in thList:
        print(th.getText())
        text += th.getText() + ','
    #print(text[:-1])
    file.write(text[:-1] + '\n')
# Out:
# Name
# Age
# Since
# Current Position

# %%
trList = bsObj.findAll('tr')

for tr in trList[1:16]:
    tdList = tr.findAll('td')
    text=""
    for td in tdList:
        print(td.getText().strip())
        text += td.getText().strip() + ','
    file.write(text[:-1] + '\n')
# Out:
# Eric Schmidt
# 61
# 2015
# Executive Chairman of the Board of Director
# Sergey Brin
# 43
# 2015
# President, Director
# Lawrence Page
# 44
# 2015
# Chief Executive Officer, Director
# Ruth Porat
# 59
# 2015
# Chief Financial Officer, Senior Vice President
# Sundar Pichai
# 45
# 2017
# Director, Chief Executive Officer, Google Inc.
# David Drummond
# 54
# 2015
# Senior Vice President - Corporate Development, Chief Legal Officer, Secretary
# John Hennessy
# 65
# 2007
# Lead Independent Director
# Diane Greene
# 61
# 2015
# Director
# L. John Doerr
# 65
# 2016
# Independent Director
# Roger Ferguson
# 65
# 2016
# Independent Director
# Ann Mather
# 57
# 2005
# Independent Director
# Alan Mulally
# 71
# 2014
# Independent Director
# Paul Otellini
# 66
# 2004
# Independent Director
# Kavitark Shriram
# 60
# 1998
# Independent Director
# Shirley Tilghman
# 70
# 2005
# Independent Director
