# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Topics:
# * Importing Python Library
# * Reading Data
# * Missing Data
# * Dealing with Categorical Data
# * Splitting Data
# * Normalize Data
